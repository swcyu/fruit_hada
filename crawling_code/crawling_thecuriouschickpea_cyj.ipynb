# %%
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import json
import re
from datetime import datetime

# 전체 페이지 수 가져오기
def get_page_num():
    url = 'https://www.thecuriouschickpea.com/'
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')

    max_num = soup.find('div', {'class': 'nav-links'}).contents[-3].text
    nums = list(range(1, int(max_num)+1))

    return nums


# 입력한 페이지의 전체 레시피 링크 가져오기
def get_links(i):
    link_list = list()
    url = 'https://www.thecuriouschickpea.com/page/' + str(i)
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    
    titles = soup.find_all('h2', {'class': 'excerpt-title'})
    
    for title in titles:
        link_list.append(title.contents[0].get('href'))
    
    return link_list


# 입력한 링크의 제목, 댓글(후기) 가져오기
def get_contents(url):
    print(url)
    try:
        contents = dict()
        soup = BeautifulSoup(requests.get(url).text, 'html.parser')

        # 제목
        title = soup.select('h1')[0].text
        contents['title'] = title

        # 재료
        ing_div = soup.find('div', {'class': 'mv-create-ingredients'})
        ing_list = list()

        if ing_div.h4:
            # h4: 소제목
            for h4 in ing_div.find_all('h4'):
                temp = dict()
                ing_temp = list()
                # li: 각 소제목 아래 재료들
                for li in h4.find_next_siblings()[0].contents:
                    if li != '\n':
                        ing_temp.append(li.text.strip())
                temp[h4.text] = ing_temp
                ing_list.append(temp)
        else:
            for li in ing_div.find_all('li'):
                ing_list.append(li.text.strip())

        contents['ingredients'] = ing_list

        # 조리시간
        contents['time'] = soup.find('div', {'class': 'mv-create-time mv-create-time-total'}).find('span').text.strip()

        # 분량
        contents['serving'] = soup.find('div', {'class': 'mv-create-time mv-create-time-yield'}).find('span').text.strip()

        # 레시피
        instr = soup.find('div', {'class': 'mv-create-instructions'}).find_all('li')
        instr_list = list()

        for i in range(len(instr)):
            instr_list.append(str(i+1) + ". " + instr[i].text)

        contents['recipe'] = instr_list

        # 영양정보
        nutri = soup.find('div', {'class': 'mv-create-nutrition-box'})
        nutri_dict = dict()

        nutri_dict['calories'] = nutri.find('span', {'class': 'mv-create-nutrition-calories'}).text.replace('Calories: ','') + 'kcal'
        nutri_dict['carbs'] = nutri.find('span', {'class': 'mv-create-nutrition-carbohydrates'}).text.replace('Carbohydrates: ','')
        nutri_dict['protein'] = nutri.find('span', {'class': 'mv-create-nutrition-protein'}).text.replace('Protein: ','')
        nutri_dict['total fat'] = nutri.find('span', {'class': 'mv-create-nutrition-total-fat'}).text.replace('Total Fat: ','')

        contents['nutrition'] = nutri_dict

        # 댓글
        page_num = soup.find('link', {'rel': 'shortlink'}).get('href')[-4:]
        comm_url = 'https://www.thecuriouschickpea.com/wp-json/wp/v2/comments?post=' + page_num +'&per_page=100'

        comments = requests.get(comm_url).json()    
        comm_list = list()
        for comment in comments:
            try:
                if (comment['author_name'] != 'thecuriouschickpea') and (comment['author_name'] != 'Eva Agha'):
                    comm_list.append(re.sub('(<([^>]+)>)', '', comment['content']['rendered']).strip())
            except:
                pass

        contents['comments'] = comm_list

        return contents
    
    except:
        pass


# 전체 페이지 레시피 가져오기
def get_all_page_comment(nums):
    total = dict()
    title_comments = list()
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        for num in nums:
            links = get_links(num)
            for link in links:
                content = executor.submit(get_contents, link)
                title_comments.append(content.result())

    date = datetime.today().strftime("%Y%m%d")
    
    total['date'] = date                
    total['thecuriouschickpea'] = title_comments
    return total


# 메인에서 실행
if __name__ == '__main__':
    nums = get_page_num()
    total = get_all_page_comment(nums)

    date = datetime.today().strftime("%Y%m%d")
        
    with open(f'D:\\fruit_hada\\crawling\\crawling_result\\{date}_thecuriouschickpea_all.json', 'w', encoding='utf-8-sig') as file:
        json.dump(total, file, indent="\t")          
        
    print("done")
# Out:
# https://www.thecuriouschickpea.com/baked-gnocchi-arrabbiata-vegan-mozzarella/
# https://www.thecuriouschickpea.com/vegan-creamy-garlic-noodles/
# https://www.thecuriouschickpea.com/vegan-homemade-restaurant-style-naan/
# https://www.thecuriouschickpea.com/vegan-white-bean-wild-rice-soup/
# https://www.thecuriouschickpea.com/vegan-french-onion-soup/
# https://www.thecuriouschickpea.com/peanut-butter-pumpkin-dog-treats/
# https://www.thecuriouschickpea.com/jamaican-red-beans-and-rice/
# https://www.thecuriouschickpea.com/jamaican-jerk-tempeh/
# https://www.thecuriouschickpea.com/jamaican-jerk-sauce/
# https://www.thecuriouschickpea.com/vegan-pumpkin-muffins/
# https://www.thecuriouschickpea.com/sweet-corn-risotto/
# https://www.thecuriouschickpea.com/vegan-seitan-steaks/
# https://www.thecuriouschickpea.com/vegan-shallot-gravy/
# https://www.thecuriouschickpea.com/smashed-potato-herbed-salad/
# https://www.thecuriouschickpea.com/tamarind-red-lentil-soup/
# https://www.thecuriouschickpea.com/vegan-caramel-sauce/
# https://www.thecuriouschickpea.com/vegan-barbacoa-tacos/
# https://www.thecuriouschickpea.com/vegan-berbere-mac-and-cheese/
# https://www.thecuriouschickpea.com/kale-salad-smokey-chickpeas-roasted-jalapeno-dressing/
# https://www.thecuriouschickpea.com/vegan-banana-nut-muffins/
# https://www.thecuriouschickpea.com/vegan-sheekh-kababs/
# https://www.thecuriouschickpea.com/vegan-skillet-pizza-dip/
# https://www.thecuriouschickpea.com/vegan-taco-pinwheels/
# https://www.thecuriouschickpea.com/gobi-manchurian/
# https://www.thecuriouschickpea.com/easy-vegan-crepes/
# https://www.thecuriouschickpea.com/peanut-tofu-spring-rolls/
# https://www.thecuriouschickpea.com/easy-vegan-baked-ziti/
# https://www.thecuriouschickpea.com/crispy-baked-buffalo-tofu-wings/
# https://www.thecuriouschickpea.com/vegan-creamy-garlic-pasta-with-shaved-brussels-sprouts/
# https://www.thecuriouschickpea.com/vegan-thousand-island-dressing/
# https://www.thecuriouschickpea.com/vegan-reuben-sandwich/
# https://www.thecuriouschickpea.com/vegan-brioche/
# https://www.thecuriouschickpea.com/vegan-mocha-cinnamon-bars/
# https://www.thecuriouschickpea.com/vegan-wishing-cookies/
# https://www.thecuriouschickpea.com/chicago-style-deep-dish-pizza/
# https://www.thecuriouschickpea.com/homemade-giardiniera/
# https://www.thecuriouschickpea.com/homemade-roti/
# https://www.thecuriouschickpea.com/homemade-cilantro-chutney/
# https://www.thecuriouschickpea.com/homemade-tamarind-chutney/
# https://www.thecuriouschickpea.com/kale-pakoras/
# https://www.thecuriouschickpea.com/creamy-vegan-mushroom-gravy/
# https://www.thecuriouschickpea.com/vegan-tandoori-sheet-pan-dinner/
# https://www.thecuriouschickpea.com/easy-homemade-hot-sauce/
# https://www.thecuriouschickpea.com/vegan-red-velvet-cupcakes/
# https://www.thecuriouschickpea.com/vegan-ermine-frosting/
# https://www.thecuriouschickpea.com/spicy-sichuan-noodles-with-eggplant/
# https://www.thecuriouschickpea.com/curried-tofu-salad/
# https://www.thecuriouschickpea.com/thai-curry-cauliflower-lentil-soup-chickpea-croutons/
# https://www.thecuriouschickpea.com/vegan-apple-pecan-cinnamon-buns/
# https://www.thecuriouschickpea.com/gochujang-tempeh-wings/
# https://www.thecuriouschickpea.com/vegan-fried-bacon-mac-and-cheese/
# https://www.thecuriouschickpea.com/vegan-rajas-con-crema/
# https://www.thecuriouschickpea.com/vegan-twice-baked-potatoes-with-collard-greens/
# https://www.thecuriouschickpea.com/vegan-mexican-chocolate-brownies/
# https://www.thecuriouschickpea.com/caramelized-onion-white-bean-dip/
# https://www.thecuriouschickpea.com/homemade-flatbread/
# https://www.thecuriouschickpea.com/vegan-german-chocolate-cupcakes/
# https://www.thecuriouschickpea.com/afghan-aushak/
# https://www.thecuriouschickpea.com/vegan-peach-pancakes/
# https://www.thecuriouschickpea.com/tomato-sweet-corn-salad/
# https://www.thecuriouschickpea.com/chickpea-and-spinach-curry/
# https://www.thecuriouschickpea.com/vegan-peach-cupcakes/
# https://www.thecuriouschickpea.com/black-bean-burrito-bowls/
# https://www.thecuriouschickpea.com/seasoned-black-beans/
# https://www.thecuriouschickpea.com/vegan-sun-dried-tomato-cream-pasta/
# https://www.thecuriouschickpea.com/vegan-pesto-cream-gnocchi/
# https://www.thecuriouschickpea.com/baingan-bharta/
# https://www.thecuriouschickpea.com/vegan-shakshuka/
# https://www.thecuriouschickpea.com/buffalo-soy-curl-pizza/
# https://www.thecuriouschickpea.com/cashew-ranch-dressing/
# https://www.thecuriouschickpea.com/easy-vegan-ricotta/
# https://www.thecuriouschickpea.com/mustard-green-pesto-potato-salad/
# https://www.thecuriouschickpea.com/vegan-chickpea-meatballs/
# https://www.thecuriouschickpea.com/restaurant-style-chana-masala/
# https://www.thecuriouschickpea.com/vegan-korean-bbq-burgers/
# https://www.thecuriouschickpea.com/homemade-vegan-gnocchi-recipe/
# https://www.thecuriouschickpea.com/vegan-tinga-tacos-avocado-crema/
# https://www.thecuriouschickpea.com/vegan-avocado-crema/
# https://www.thecuriouschickpea.com/kimchi-slaw/
# https://www.thecuriouschickpea.com/korean-bbq-sauce/
# https://www.thecuriouschickpea.com/penne-buffalo-cauliflower-cream-sauce/
# https://www.thecuriouschickpea.com/homemade-vegan-wontons/
# https://www.thecuriouschickpea.com/dumpling-dipping-sauce/
# https://www.thecuriouschickpea.com/vegan-chocolate-chip-marshmallow-cookies/
# https://www.thecuriouschickpea.com/cocktail-chana-samosa/
# https://www.thecuriouschickpea.com/homemade-raspberry-scones/
# https://www.thecuriouschickpea.com/vegan-irish-stew/
# https://www.thecuriouschickpea.com/homemade-kale-soda-bread/
# https://www.thecuriouschickpea.com/easy-vegan-carrot-cake/
# https://www.thecuriouschickpea.com/vegan-cream-cheese-frosting/
# https://www.thecuriouschickpea.com/no-boil-vegan-mac-and-cheese/
# https://www.thecuriouschickpea.com/restaurant-style-aloo-matar/
# https://www.thecuriouschickpea.com/homemade-scallion-pancakes/
# https://www.thecuriouschickpea.com/easy-homemade-vegan-chili/
# https://www.thecuriouschickpea.com/burmese-kaukswe/
# https://www.thecuriouschickpea.com/refried-bean-dip/
# https://www.thecuriouschickpea.com/vegan-garlic-parmesan-potato-stacks/
# https://www.thecuriouschickpea.com/vegan-breakfast-hash/
# https://www.thecuriouschickpea.com/vegan-hollandaise/
# https://www.thecuriouschickpea.com/chorizo-chickpeas/
# https://www.thecuriouschickpea.com/garlic-urad-dal-fry/
# https://www.thecuriouschickpea.com/afghan-kidney-bean-curry/
# https://www.thecuriouschickpea.com/tofu-buddha-bowl-with-carrot-ginger-dressing/
# https://www.thecuriouschickpea.com/walnut-parsley-linguine/
# https://www.thecuriouschickpea.com/vegan-lentil-enchiladas/
# https://www.thecuriouschickpea.com/homemade-enchilada-sauce/
# https://www.thecuriouschickpea.com/vegan-butternut-squash-queso/
# https://www.thecuriouschickpea.com/homemade-tunisian-harissa/
# https://www.thecuriouschickpea.com/harissa-roasted-brussels-sprouts/
# https://www.thecuriouschickpea.com/cranberry-barbecue-cauliflower-wings/
# https://www.thecuriouschickpea.com/easy-vegan-cornbread/
# https://www.thecuriouschickpea.com/vegan-thanksgiving-roundup/
# https://www.thecuriouschickpea.com/delicious-vegan-indian-recipes/
# https://www.thecuriouschickpea.com/vegan-classic-apple-cider-donuts/
# https://www.thecuriouschickpea.com/vegan-cabbage-potato-and-chickpea-sheet-pan-dinner/
# https://www.thecuriouschickpea.com/vegan-baked-potato-skins/
# https://www.thecuriouschickpea.com/broccoli-in-garlic-sauce/
# https://www.thecuriouschickpea.com/vegan-chicken-parmesan-sandwiches/
# https://www.thecuriouschickpea.com/vegan-chicken-seitan-cutlets/
# https://www.thecuriouschickpea.com/tofu-with-black-bean-sauce/
# https://www.thecuriouschickpea.com/vegan-potato-and-zucchini-gratin/
# https://www.thecuriouschickpea.com/hoisin-eggplant-bao/
# https://www.thecuriouschickpea.com/bhindi-masala-indian-okra/
# https://www.thecuriouschickpea.com/pesto-smashed-potato-pizzas/
# https://www.thecuriouschickpea.com/vegan-masala-curry-mac-and-cheese/
# https://www.thecuriouschickpea.com/watermelon-mint-agua-fresca/
# https://www.thecuriouschickpea.com/cauliflower-moilee-curry/
# https://www.thecuriouschickpea.com/smoky-collard-greens/
# https://www.thecuriouschickpea.com/chipotle-barbecue-tofu-with-smokey-collard-greens/
# https://www.thecuriouschickpea.com/chipotle-barbecue-sauce/
# https://www.thecuriouschickpea.com/easy-overnight-pizza-dough/
# https://www.thecuriouschickpea.com/zaatar-pasta-salad/
# https://www.thecuriouschickpea.com/baja-tofu-tacos/
# https://www.thecuriouschickpea.com/quick-pickled-radishes/
# https://www.thecuriouschickpea.com/homemade-salsa-verde/
# https://www.thecuriouschickpea.com/vegan-almond-rhubarb-bundt-cake/
# https://www.thecuriouschickpea.com/garlic-scape-pizza/
# https://www.thecuriouschickpea.com/marinated-zucchini-with-mint-and-thai-basil/
# https://www.thecuriouschickpea.com/grilled-salad-with-smoky-lentils/
# https://www.thecuriouschickpea.com/pesto-cashew-aioli/
# https://www.thecuriouschickpea.com/vegan-sprouting-broccoli-quiche/
# https://www.thecuriouschickpea.com/herbed-chickpea-burgers/
# https://www.thecuriouschickpea.com/vegan-milk-bread-buns/
# https://www.thecuriouschickpea.com/roasted-jalapeno-and-cilantro-hummus/
# https://www.thecuriouschickpea.com/vegan-classic-potato-salad/
# https://www.thecuriouschickpea.com/vegan-vodka-sauce/
# https://www.thecuriouschickpea.com/crispy-coconut-tofu-poke-bowl-with-wasabi-sauce/
# https://www.thecuriouschickpea.com/blackberry-lavender-chocolate-cake/
# https://www.thecuriouschickpea.com/shredded-mushroom-carnitas/
# https://www.thecuriouschickpea.com/pesto-leek-pizza-with-coconut-bacon/
# https://www.thecuriouschickpea.com/roasted-broccoli-buddha-bowls/
# https://www.thecuriouschickpea.com/homemade-salvadoran-pupusas/
# https://www.thecuriouschickpea.com/salvadoran-salsa-roja-tomato-sauce/
# https://www.thecuriouschickpea.com/salvadorian-curtido/
# https://www.thecuriouschickpea.com/homemade-cultured-cashew-cream-cheese/
# https://www.thecuriouschickpea.com/garlic-linguine-with-vegan-whipped-pea-ricotta/
# https://www.thecuriouschickpea.com/vegan-ramen-with-miso-tahini-broth/
# https://www.thecuriouschickpea.com/barbecue-tofu-sandwiches-with-pineapple-relish/
# https://www.thecuriouschickpea.com/masoor-dal-tadka/
# https://www.thecuriouschickpea.com/vegan-massaman-curry/
# https://www.thecuriouschickpea.com/massaman-curry-paste-recipe/
# https://www.thecuriouschickpea.com/chai-spice-loaf-cake-vegan/
# https://www.thecuriouschickpea.com/vegan-chocolate-chip-pancakes/
# https://www.thecuriouschickpea.com/vegan-classic-caesar-salad-dressing/
# https://www.thecuriouschickpea.com/favosalata-yellow-split-pea-dip/
# https://www.thecuriouschickpea.com/vegan-creamy-asparagus-and-leek-pasta/
# https://www.thecuriouschickpea.com/indian-spiced-chickpeas-greens/
# https://www.thecuriouschickpea.com/homemade-soft-pretzels-with-mustard-beer-dip/
# https://www.thecuriouschickpea.com/dark-chocolate-crepe-cake/
# https://www.thecuriouschickpea.com/waffle-fry-nachos/
# https://www.thecuriouschickpea.com/vegan-meatballs-in-roasted-red-pepper-sauce/
# https://www.thecuriouschickpea.com/vegan-stromboli/
# https://www.thecuriouschickpea.com/homemade-seitan-deli-meat-slices/
# https://www.thecuriouschickpea.com/gochujang-tofu-dumplings/
# https://www.thecuriouschickpea.com/vegan-peanut-butter-oatmeal-chocolate-chip-cookies/
# https://www.thecuriouschickpea.com/kale-salad-with-roasted-garlic-tahini-dressing/
# https://www.thecuriouschickpea.com/vegan-mango-jalapeno-jello-shots/
# https://www.thecuriouschickpea.com/classic-homemade-marinara-with-spinach/
# https://www.thecuriouschickpea.com/vegan-cheesy-beefy-taquitos/
# https://www.thecuriouschickpea.com/curry-sweet-potato-kale-and-peanut-stew/
# https://www.thecuriouschickpea.com/sindhi-vegetable-biryani/
# https://www.thecuriouschickpea.com/vegan-buffalo-wing-mac-and-cheese/
# https://www.thecuriouschickpea.com/vegan-raita-indian-cucumber-and-mint-yogurt-sauce/
# https://www.thecuriouschickpea.com/vegan-double-chocolate-banana-muffins/
# https://www.thecuriouschickpea.com/jamaican-black-eyed-pea-curry/
# https://www.thecuriouschickpea.com/easy-vegan-mushroom-lasagna-skillet/
# https://www.thecuriouschickpea.com/crispy-orange-seitan-and-broccoli/
# https://www.thecuriouschickpea.com/vegan-chocolate-glazed-doughnuts/
# https://www.thecuriouschickpea.com/tibetan-vegetable-momos-with-spicy-sesame-tomato-chutney/
# https://www.thecuriouschickpea.com/vegan-cheese-fondue/
# https://www.thecuriouschickpea.com/vegan-hazelnut-cake-with-whipped-chocolate-ganache/
# https://www.thecuriouschickpea.com/pumpkin-mole-with-grilled-tofu-and-mexican-tomato-rice/
# https://www.thecuriouschickpea.com/sticky-teriyaki-tofu-and-cauliflower/
# https://www.thecuriouschickpea.com/seitan-roast-stuffed-with-chestnut-white-wine-risotto/
# https://www.thecuriouschickpea.com/vegan-chocolate-bourbon-pecan-pie/
# https://www.thecuriouschickpea.com/easy-vegan-pie-dough/
# https://www.thecuriouschickpea.com/vegan-broccoli-fritters/
# https://www.thecuriouschickpea.com/vegan-dal-makhani/
# https://www.thecuriouschickpea.com/creamy-mushroom-penne-vegan-reset-cookbook-review/
# https://www.thecuriouschickpea.com/tandoori-cauliflower-and-seitan-bake/
# https://www.thecuriouschickpea.com/roasted-eggplant-pizza-with-almond-ricotta-and-chili-oil/
# https://www.thecuriouschickpea.com/homemade-chili-oil/
# https://www.thecuriouschickpea.com/chimichurri-loaded-sweet-potato-fries/
# https://www.thecuriouschickpea.com/vegan-caramelized-mushroom-pizza/
# https://www.thecuriouschickpea.com/vegan-black-lentil-bolognese/
# https://www.thecuriouschickpea.com/easy-vegan-vanilla-cake/
# https://www.thecuriouschickpea.com/pasta-romesco-with-crispy-baked-tofu/
# https://www.thecuriouschickpea.com/soft-whole-wheat-dinner-rolls/
# https://www.thecuriouschickpea.com/butternut-squash-almond-bisque/
# https://www.thecuriouschickpea.com/easy-romesco-sauce/
# https://www.thecuriouschickpea.com/vegan-spinach-artichoke-dip/
# https://www.thecuriouschickpea.com/vegan-tempeh-blt-sandwiches/
# https://www.thecuriouschickpea.com/vegan-chickpea-meatball-subs-with-homemade-mozzarella/
# https://www.thecuriouschickpea.com/papas-rajas-tacos/
# https://www.thecuriouschickpea.com/creamy-mexican-chipotle-sauce-with-aquafaba/
# https://www.thecuriouschickpea.com/sun-dried-tomato-and-kale-pesto/
# https://www.thecuriouschickpea.com/vegan-strawberry-shortcake/
# https://www.thecuriouschickpea.com/vegan-curry-seitan-and-black-eyed-pea-burgers-gluten-free-option/
# https://www.thecuriouschickpea.com/easy-vegan-roasted-carrot-soup/
# https://www.thecuriouschickpea.com/vegan-pepperoni-pan-pizza/
# https://www.thecuriouschickpea.com/omars-top-curious-chickpea-recipes-summer-2018/
# https://www.thecuriouschickpea.com/gochujang-peanut-noodles-with-patty-pan-squash/
# https://www.thecuriouschickpea.com/whole-grain-cornmeal-vegan-pancake-mix/
# https://www.thecuriouschickpea.com/creamy-vegan-barley-risotto-stuffed-zucchini/
# https://www.thecuriouschickpea.com/vegan-aquafaba-strawberry-italian-meringue-buttercream/
# https://www.thecuriouschickpea.com/vegan-chocolate-cake/
# https://www.thecuriouschickpea.com/vegan-jalapeno-popper-dip/
# https://www.thecuriouschickpea.com/buffalo-chickpea-rice-paper-wraps-with-tahini-ranch-dip/
# https://www.thecuriouschickpea.com/vegan-breakfast-egg-and-sausage-muffins/
# https://www.thecuriouschickpea.com/vegan-garlic-pesto-alfredo-pasta-with-grilled-garlic-scapes/
# https://www.thecuriouschickpea.com/vegan-tempeh-maple-breakfast-sausage-patties/
# https://www.thecuriouschickpea.com/afghan-cauliflower-and-tofu-tikka-kebab-skewers/
# https://www.thecuriouschickpea.com/chewy-vegan-tahini-chocolate-chip-cookies/
# https://www.thecuriouschickpea.com/vegan-pizza-primavera/
# https://www.thecuriouschickpea.com/curried-chickpea-and-mango-salad-with-vegan-queso-fresco/
# https://www.thecuriouschickpea.com/vegan-seitan-carne-asada-tacos/
# https://www.thecuriouschickpea.com/vegan-kung-pao-tofu/
# https://www.thecuriouschickpea.com/grilled-homemade-seitan-steaks-with-mashed-potatoes-and-shallot-gravy/
# https://www.thecuriouschickpea.com/easy-homemade-vegan-queso-fresco/
# https://www.thecuriouschickpea.com/vegan-palak-tofu-paneer/
# https://www.thecuriouschickpea.com/vegan-battered-tofu-mexican-tortas/
# https://www.thecuriouschickpea.com/the-ultimate-homemade-sandwich-rolls/
# https://www.thecuriouschickpea.com/spaghetti-with-roasted-eggplant-marinara-and-vegan-lentil-meatballs/
# https://www.thecuriouschickpea.com/cajun-soy-curls-and-creamy-vegan-jalapeno-grits/
# https://www.thecuriouschickpea.com/vegan-smothered-burritos-with-red-sauce/
# https://www.thecuriouschickpea.com/mexican-red-chile-sauce/
# https://www.thecuriouschickpea.com/hoisin-glazed-tempeh-bowls/
# https://www.thecuriouschickpea.com/vegan-singapore-noodles/
# https://www.thecuriouschickpea.com/savory-crepes-with-almond-cheese-sauteed-spinach-and-vegan-hollandaise/
# https://www.thecuriouschickpea.com/roasted-sweet-potato-and-farro-salad-with-garlicky-chickpeas/
# https://www.thecuriouschickpea.com/vegan-mango-tarts-with-vanilla-pastry-cream/
# https://www.thecuriouschickpea.com/crispy-kale-roasted-tomato-and-vegan-chicken-white-sauce-pizza/
# https://www.thecuriouschickpea.com/vegan-gochujang-bean-burgers/
# https://www.thecuriouschickpea.com/vegan-garlic-white-sauce/
# https://www.thecuriouschickpea.com/vegan-chipotle-mac-and-cheese-with-spicy-tempeh-crumbles/
# https://www.thecuriouschickpea.com/vegan-potato-leek-soup/
# https://www.thecuriouschickpea.com/vegan-malai-kofta-indian-dumplings-in-curry-tomato-cream-sauce/
# https://www.thecuriouschickpea.com/vegan-brown-butter-gnocchi/
# https://www.thecuriouschickpea.com/vegan-chipotle-seitan-cheese-tamale-skillet-pie/
# https://www.thecuriouschickpea.com/vegan-thai-green-curry-tofu/
# https://www.thecuriouschickpea.com/roasted-jalapeno-cheese/
# https://www.thecuriouschickpea.com/vegan-chocolate-hazelnut-truffles/
# https://www.thecuriouschickpea.com/dill-salad-lemon-tahini-yogurt-dressing/
# https://www.thecuriouschickpea.com/mexican-pinto-beans-and-tomatillo-cilantro-lime-rice/
# https://www.thecuriouschickpea.com/vegan-rocky-road-brownies/
# https://www.thecuriouschickpea.com/quick-and-easy-homemade-breadsticks-with-spicy-marinara/
# https://www.thecuriouschickpea.com/seared-seitan-mushroom-pozole-rojo/
# https://www.thecuriouschickpea.com/green-curry-noodles-broccoli-mushrooms/
# https://www.thecuriouschickpea.com/homemade-thai-green-curry-paste/
# https://www.thecuriouschickpea.com/vegan-risotto-bolognese/
# https://www.thecuriouschickpea.com/mustard-roasted-cauliflower-roasted-red-pepper-sauce/
# https://www.thecuriouschickpea.com/vegan-spaghetti-ai-funghi-spaghetti-and-mushrooms-in-vegan-cream-sauce/
# https://www.thecuriouschickpea.com/vegan-peppermint-candy-cane-cookies/
# https://www.thecuriouschickpea.com/creamy-broccoli-cauliflower-soup-potato-dumplings-crispy-vegan-bacon/
# https://www.thecuriouschickpea.com/vegan-mattar-tofu-paneer/
# https://www.thecuriouschickpea.com/lemon-chickpeas-rice/
# https://www.thecuriouschickpea.com/egg-free-vegan-homemade-black-pepper-pasta/
# https://www.thecuriouschickpea.com/vegan-curried-eggplant-pizza/
# https://www.thecuriouschickpea.com/easy-stovetop-apple-butter-recipe/
# https://www.thecuriouschickpea.com/madras-curry-marinated-eggplant/
# https://www.thecuriouschickpea.com/tahini-pasta-skillet-sweet-potato-kale/
# https://www.thecuriouschickpea.com/vegan-sweet-potato-rolls/
# https://www.thecuriouschickpea.com/black-bean-soup-pepita-cream/
# https://www.thecuriouschickpea.com/leek-bolani-afghan-leek-stuffed-flatbread/
# https://www.thecuriouschickpea.com/afghan-chutney-2-ways/
# https://www.thecuriouschickpea.com/vegan-cheesy-eggplant-casserole/
# https://www.thecuriouschickpea.com/vegan-curry-seitan-steamed-buns/
# https://www.thecuriouschickpea.com/miso-glazed-eggplant-tacos/
# https://www.thecuriouschickpea.com/spicy-roasted-tomato-salsa/
# https://www.thecuriouschickpea.com/vegan-chipotle-cheese-spread/
# https://www.thecuriouschickpea.com/vegan-mexican-pizza/
# https://www.thecuriouschickpea.com/coconut-ginger-custard-filled-doughnuts/
# https://www.thecuriouschickpea.com/beer-braised-zucchini/
# https://www.thecuriouschickpea.com/homemade-new-york-style-bagels/
# https://www.thecuriouschickpea.com/quick-pickled-grapes/
# https://www.thecuriouschickpea.com/vegan-jalapeno-cheese-biscuits/
# https://www.thecuriouschickpea.com/vegan-southwestern-black-bean-burgers/
# https://www.thecuriouschickpea.com/broccoli-tofu-black-bean-sauce/
# https://www.thecuriouschickpea.com/vegan-homemade-pretzel-buns/
# https://www.thecuriouschickpea.com/stuffed-mediterranean-veggie-burgers-greek-marinated-tomatoes/
# https://www.thecuriouschickpea.com/vegan-roasted-jalapeno-poppers/
# https://www.thecuriouschickpea.com/creamy-vegan-almond-cheese/
# https://www.thecuriouschickpea.com/vegan-sweet-corn-veloute/
# https://www.thecuriouschickpea.com/spaghetti-sun-dried-tomato-cream-chickpea-meatballs/
# https://www.thecuriouschickpea.com/tamarind-glazed-tempeh-stir-fried-vegetables-rice-noodles/
# https://www.thecuriouschickpea.com/cauliflower-french-lentils-smokey-red-pepper-sauce/
# https://www.thecuriouschickpea.com/vegan-mango-lassi/
# https://www.thecuriouschickpea.com/overnight-artisan-walnut-bread/
# https://www.thecuriouschickpea.com/same-day-vegan-mozzarella-cheese/
# https://www.thecuriouschickpea.com/penne-with-white-wine-cream-sauce-and-broccolini/
# https://www.thecuriouschickpea.com/miso-hoisin-glazed-tofu-and-baby-bok-choy/
# https://www.thecuriouschickpea.com/vegan-potato-pan-pizza/
# https://www.thecuriouschickpea.com/pea-ricotta-stuffed-shells-with-red-wine-marinara/
# https://www.thecuriouschickpea.com/black-lentil-urad-dal/
# https://www.thecuriouschickpea.com/chickpea-and-couscous-stuffed-red-bell-peppers/
# https://www.thecuriouschickpea.com/vegan-eggy-bacon-and-chive-muffins/
# https://www.thecuriouschickpea.com/vegan-cheeseburger-pizza-vodka-sauce-caramelized-onions/
# https://www.thecuriouschickpea.com/roasted-garlic-sweet-potato-mac-and-cheese/
# https://www.thecuriouschickpea.com/vegan-chocolate-bottomed-coconut-macaroons/
# https://www.thecuriouschickpea.com/kale-kofta-kadhi/
# https://www.thecuriouschickpea.com/vegan-asparagus-pizza-spicy-chickpea-sauce/
# https://www.thecuriouschickpea.com/corned-tempeh-pasties/
# https://www.thecuriouschickpea.com/chipotle-black-bean-and-sweet-potato-enchiladas/
# https://www.thecuriouschickpea.com/golden-chickpeas-curried-cauliflower/
# https://www.thecuriouschickpea.com/vegan-jalapeno-cheese-bean-pupusas/
# https://www.thecuriouschickpea.com/sangria-gels-brandy-caramelized-pears/
# https://www.thecuriouschickpea.com/tofu-udon-almond-butter-stir-fry/
# https://www.thecuriouschickpea.com/vegan-meatball-pesto-pizza/
# https://www.thecuriouschickpea.com/vegan-potato-sausage-quiche/
# done
