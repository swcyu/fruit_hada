# %%
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import json
from html import unescape
from time import sleep
import random
from datetime import datetime

# 전체 페이지 수 가져오기
def get_page_num():
    url = 'https://lovingitvegan.com/category/recipe/'
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    max_num = soup.find('div', {'class': 'nav-links'}).contents[-3].text
    nums = list(range(1, (int(max_num) + 1)))

    return nums


# 입력한 페이지의 전체 레시피 링크 가져오기
def get_links(i):
    link_list = list()

    url = 'https://lovingitvegan.com/category/recipe/page/' + str(i)
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    articles = soup.find_all('li', {'class': 'listing-item'})
    for article in articles:
        try:
            link_list.append(article.contents[1].get('href'))
        except:
            pass

    return link_list

# 입력한 링크의 제목, 댓글, 레시피, 재료, 조리시간, 분량, 영양정보, 이미지 가져오기
def get_contents(url):
    contents = dict()
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')

    # 제목
    title = soup.find('h1', {'class': 'entry-title'})
    if title:
        title = title.text
    else:
        pass

    # 댓글
    com_list = list()

    comments = soup.find_all('ol', {'class': 'comment-list'})
    for comment in comments:
        for c_num in range(1, 10000, 3):
            try:
                com_list.append((comment.contents[c_num].contents[1].contents[3].text).strip('\n'))
            except:
                pass

    ## 댓글의 갯수
    comments_num = len(com_list) + 1

    # 레시피
    recipes_list = list()
    steps_list = list()
    recipes = soup.find_all('li', {'class': 'wprm-recipe-instruction'})
    for recipe in recipes:
        if recipe:
            step = str(int(recipe.get('id').split('-')[-1]) + 1)
            recipes_list.append(step + '. ' + recipe.text)
        else:
            pass

    # 재료
    ingredients_list = list()
    ingredients = soup.find_all('input', {'class': 'wprm-checkbox'})
    for ingredient in ingredients:
        if ingredient:
            ingredients_list.append(ingredient.get('aria-label'))
        else:
            pass

    # 조리시간
    cooktime = ''
    cooktimes = soup.find_all('span', {'class': 'wprm-recipe-time wprm-block-text-normal'})
    if cooktimes:
        cooktime = cooktimes[-1].text
    else:
        cooktime = ''

    # 분량
    servings = soup.find('span', {
        'class': 'wprm-recipe-servings wprm-recipe-details wprm-recipe-servings-41441 wprm-recipe-servings-adjustable-disabled wprm-block-text-normal'})
    if servings:
        servings = servings.text
    else:
        servings = ''

    # 영양정보
    calories = soup.find('span', {
        'class': 'wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-calories'})
    if calories:
        calories = calories.text.split(' ')[-1]
    else:
        calories = ''

    carbs = soup.find('span', {'class',
                              'wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-carbohydrates'})
    if carbs:
        carbs = carbs.text.split(' ')[-1]
    else:
        carbs = ''

    protein = soup.find('span', {
        'class': 'wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-protein'})
    if protein:
        protein = protein.text.split(' ')[-1]
    else:
        protein = ''

    fat = soup.find('span', {
        'class': 'wprm-nutrition-label-text-nutrition-container wprm-nutrition-label-text-nutrition-container-fat'})
    if fat:
        total_fat = fat.text.split(' ')[-1]
    else:
        total_fat = ''

    # 이미지
    image = soup.find('figure', {'class', 'wp-block-image size-full'})
    if image:
        image = image.contents[0].get('src')
    else:
        pass

    if recipes_list != {}:
        if comments_num > 4:
            # 주소 (사이트)
            contents['site'] = url
            # 제목
            contents['title'] = title
            # 재료
            contents['ingredients'] = ingredients_list
            # 조리시간
            contents['time'] = cooktime
            # 분량
            contents['serving'] = servings
            # 레시피 내용
            contents['recipe'] = recipes_list
            # 칼로리
            contents['calories'] = calories
            # 탄수화물
            contents['carbs'] = carbs
            # 단백질
            contents['protein'] = protein
            # 지방
            contents['total_fat'] = total_fat
            # 댓글
            contents['comments'] = com_list
            # 이미지
            contents['image'] = image
        else:
            pass
    else:
        contents = ''

    print('#', comments_num, '-url: ', url)

    return contents

# 전체 페이지 레시피 댓글 가져오기
def get_all_page_comment(nums):
    total = dict()
    title_comments = list()

    with ThreadPoolExecutor(max_workers=10) as executor:
        for num in nums:
            links = get_links(num)
            for link in links:
                content = executor.submit(get_contents, link)
                title_comments.append(content.result())
                a = random.randrange(1, 11)
                sleep(a)

    date = datetime.today().strftime("%Y%m%d")
    
    total['date'] = date                
    total['lovingitvegan'] = title_comments
    return total


# 메인에서 실행
if __name__ == '__main__':
    nums = get_page_num()
    total = get_all_page_comment(nums)

    date = datetime.today().strftime("%Y%m%d")
        
    with open(f'D:\\fruit_hada\\crawling\\crawling_result\\{date}_lovingitvegan_all.json', 'w', encoding='utf-8-sig') as file:
        json.dump(total, file, indent="\t")
# Out:
# # 1 -url:  https://lovingitvegan.com/vegan-brown-sugar-cookies/
# # 4 -url:  https://lovingitvegan.com/vegan-oatmeal-cranberry-cookies/
# # 2 -url:  https://lovingitvegan.com/vegan-artichoke-dip/
# # 6 -url:  https://lovingitvegan.com/vegan-gingerbread-loaf/
# # 4 -url:  https://lovingitvegan.com/vegan-pumpkin-pasta/
# # 13 -url:  https://lovingitvegan.com/vegan-feta/
# # 3 -url:  https://lovingitvegan.com/vegan-pumpkin-scones/
# # 2 -url:  https://lovingitvegan.com/vegan-stuffing/
# # 3 -url:  https://lovingitvegan.com/jackfruit-curry/
# # 4 -url:  https://lovingitvegan.com/vegan-pumpkin-oatmeal-cookies/
# # 1 -url:  https://lovingitvegan.com/vegan-pumpkin-waffles/
# # 7 -url:  https://lovingitvegan.com/vegan-cowboy-cookies/
# # 4 -url:  https://lovingitvegan.com/chocolate-sheet-cake-with-chocolate-fudge-frosting/
# # 8 -url:  https://lovingitvegan.com/easiest-baba-ganoush/
# # 2 -url:  https://lovingitvegan.com/vegan-peanut-butter-brownies/
# # 9 -url:  https://lovingitvegan.com/thai-red-curry/
# # 2 -url:  https://lovingitvegan.com/vegan-halloumi/
# # 3 -url:  https://lovingitvegan.com/vegan-stuffed-mushrooms/
# # 7 -url:  https://lovingitvegan.com/vegan-blueberry-scones/
# # 2 -url:  https://lovingitvegan.com/vegan-tortillas/
# # 9 -url:  https://lovingitvegan.com/butternut-squash-curry-bowls/
# # 6 -url:  https://lovingitvegan.com/vegan-vanilla-wafers/
# # 15 -url:  https://lovingitvegan.com/vegan-stuffed-peppers/
# # 3 -url:  https://lovingitvegan.com/vegan-granola/
# # 6 -url:  https://lovingitvegan.com/vegan-honey/
# # 6 -url:  https://lovingitvegan.com/classic-vegan-waffles/
# # 10 -url:  https://lovingitvegan.com/vegan-chocolate-pudding/
# # 10 -url:  https://lovingitvegan.com/vegan-poke-bowl/
# # 3 -url:  https://lovingitvegan.com/vegan-biryani/
# # 7 -url:  https://lovingitvegan.com/vegan-salmon/
# # 16 -url:  https://lovingitvegan.com/vegan-rice-krispie-treats/
# # 2 -url:  https://lovingitvegan.com/vegan-burger/
# # 5 -url:  https://lovingitvegan.com/vegan-tzatziki/
# # 4 -url:  https://lovingitvegan.com/vegan-fudge/
# # 4 -url:  https://lovingitvegan.com/vegan-ground-beef/
# # 15 -url:  https://lovingitvegan.com/vegan-meatballs/
# # 3 -url:  https://lovingitvegan.com/vegan-mascarpone/
# # 4 -url:  https://lovingitvegan.com/carrot-dogs/
# # 4 -url:  https://lovingitvegan.com/vegan-dark-chocolate-popsicles/
# # 11 -url:  https://lovingitvegan.com/vegan-lemon-poppy-seed-cake/
# # 8 -url:  https://lovingitvegan.com/vegan-clam-chowder/
# # 3 -url:  https://lovingitvegan.com/vegan-oatmeal-pancakes/
# # 5 -url:  https://lovingitvegan.com/vegan-biscotti/
# # 9 -url:  https://lovingitvegan.com/tofu-and-eggplant-bowls/
# # 2 -url:  https://lovingitvegan.com/how-to-cook-basmati-rice/
# # 7 -url:  https://lovingitvegan.com/vegan-zuppa-toscana/
# # 2 -url:  https://lovingitvegan.com/vegan-refried-beans/
# # 11 -url:  https://lovingitvegan.com/vegan-macaroni-salad/
# # 6 -url:  https://lovingitvegan.com/vegan-egg-salad/
# # 5 -url:  https://lovingitvegan.com/vegan-spinach-soup/
# # 9 -url:  https://lovingitvegan.com/vegan-pad-thai/
# # 3 -url:  https://lovingitvegan.com/vegan-creamed-spinach/
# # 5 -url:  https://lovingitvegan.com/vegan-chocolate-fudge-cake/
# # 3 -url:  https://lovingitvegan.com/vegan-broccoli-salad/
# # 13 -url:  https://lovingitvegan.com/vegan-green-curry/
# # 4 -url:  https://lovingitvegan.com/lentil-ragu/
# # 10 -url:  https://lovingitvegan.com/vegan-apple-muffins/
# # 1 -url:  https://lovingitvegan.com/vegan-shakshuka/
# # 8 -url:  https://lovingitvegan.com/vegan-chocolate-chip-muffins/
# # 4 -url:  https://lovingitvegan.com/vegan-dal-makhani/
# # 1 -url:  https://lovingitvegan.com/vegan-fish-tacos/
# # 3 -url:  https://lovingitvegan.com/vegan-broccoli-pasta/
# # 9 -url:  https://lovingitvegan.com/vegan-banana-chocolate-chip-muffins/
# # 6 -url:  https://lovingitvegan.com/vegan-chicken-salad/
# # 4 -url:  https://lovingitvegan.com/rich-creamy-tomato-soup/
# # 6 -url:  https://lovingitvegan.com/vegan-fried-chicken/
# # 6 -url:  https://lovingitvegan.com/vegan-biscoff-cupcakes/
# # 3 -url:  https://lovingitvegan.com/vegan-spaghetti-sauce/
# # 3 -url:  https://lovingitvegan.com/spicy-vegan-carrot-soup/
# # 14 -url:  https://lovingitvegan.com/stuffed-roasted-butternut-gluten-free/
# # 14 -url:  https://lovingitvegan.com/vegan-chili/
# # 8 -url:  https://lovingitvegan.com/veggie-fajitas/
# # 4 -url:  https://lovingitvegan.com/vegan-fish/
# # 4 -url:  https://lovingitvegan.com/vegan-millionaire-shortbread/
# # 9 -url:  https://lovingitvegan.com/lentil-bolognese/
# # 1 -url:  https://lovingitvegan.com/vegan-crab-cakes/
# # 6 -url:  https://lovingitvegan.com/vegan-chicken-noodle-soup/
# # 7 -url:  https://lovingitvegan.com/vegan-jambalaya/
# # 14 -url:  https://lovingitvegan.com/strawberry-cashew-yogurt/
# # 6 -url:  https://lovingitvegan.com/vegan-scallops/
# # 3 -url:  https://lovingitvegan.com/vegan-biscoff-brownies/
# # 7 -url:  https://lovingitvegan.com/vegan-goulash/
# # 4 -url:  https://lovingitvegan.com/vegan-shrimp/
# # 5 -url:  https://lovingitvegan.com/jackfruit-tacos/
# # 3 -url:  https://lovingitvegan.com/vegan-peanut-butter-blossoms/
# # 10 -url:  https://lovingitvegan.com/vegan-biscoff-cake/
# # 5 -url:  https://lovingitvegan.com/vegan-red-velvet-cookies/
# # 6 -url:  https://lovingitvegan.com/vegan-chicken-nuggets/
# # 9 -url:  https://lovingitvegan.com/vegan-beer-bread/
# # 9 -url:  https://lovingitvegan.com/vegan-yum-yum-sauce/
# # 1 -url:  https://lovingitvegan.com/vegan-garlic-mushrooms/
# # 6 -url:  https://lovingitvegan.com/vegan-celery-soup/
# # 2 -url:  https://lovingitvegan.com/vegan-buffalo-chicken-dip/
# # 9 -url:  https://lovingitvegan.com/creamy-asparagus-pasta/
# # 4 -url:  https://lovingitvegan.com/vegan-frosted-sugar-cookies/
# # 8 -url:  https://lovingitvegan.com/vegan-snowball-cookies/
# # 8 -url:  https://lovingitvegan.com/vegan-no-bake-cookies/
# # 7 -url:  https://lovingitvegan.com/vegan-butter-cookies/
# # 4 -url:  https://lovingitvegan.com/bang-bang-cauliflower/
# # 7 -url:  https://lovingitvegan.com/vegan-eggplant-parmesan/
# # 13 -url:  https://lovingitvegan.com/vegan-carrot-muffins/
# # 3 -url:  https://lovingitvegan.com/vegan-matcha-cookies/
# # 5 -url:  https://lovingitvegan.com/vegan-focaccia/
# # 4 -url:  https://lovingitvegan.com/vegan-banana-cupcakes/
# # 2 -url:  https://lovingitvegan.com/vegan-peanut-butter-frosting/
# # 8 -url:  https://lovingitvegan.com/vegan-buttermilk-pancakes/
# # 5 -url:  https://lovingitvegan.com/vegan-baked-ziti/
# # 15 -url:  https://lovingitvegan.com/vegan-vanilla-mug-cake/
# # 10 -url:  https://lovingitvegan.com/vegan-turkey-roast/
# # 10 -url:  https://lovingitvegan.com/vegan-goat-cheese/
# # 5 -url:  https://lovingitvegan.com/vegan-pumpkin-chocolate-chip-cookies/
# # 10 -url:  https://lovingitvegan.com/air-fryer-tofu/
# # 6 -url:  https://lovingitvegan.com/vegan-blue-cheese/
# # 5 -url:  https://lovingitvegan.com/jackfruit-pulled-pork/
# # 2 -url:  https://lovingitvegan.com/vegan-kebabs/
# # 12 -url:  https://lovingitvegan.com/vegan-heavy-cream-substitute/
# # 8 -url:  https://lovingitvegan.com/vegan-buffalo-cauliflower/
# # 4 -url:  https://lovingitvegan.com/vegan-chana-masala/
# # 3 -url:  https://lovingitvegan.com/vegan-brie/
# # 6 -url:  https://lovingitvegan.com/vegan-dumplings/
# # 4 -url:  https://lovingitvegan.com/bbq-tofu/
# # 8 -url:  https://lovingitvegan.com/vegan-baked-beans/
# # 5 -url:  https://lovingitvegan.com/bbq-cauliflower-wings/
# # 3 -url:  https://lovingitvegan.com/vegan-cookie-dough/
# # 8 -url:  https://lovingitvegan.com/vegan-stir-fry/
# # 5 -url:  https://lovingitvegan.com/vegan-cauliflower-curry/
# # 6 -url:  https://lovingitvegan.com/vegan-chipotle-sauce/
# # 12 -url:  https://lovingitvegan.com/vegan-blueberry-waffles/
# # 14 -url:  https://lovingitvegan.com/cashew-cream/
# # 14 -url:  https://lovingitvegan.com/vegan-cornbread-muffins/
# # 9 -url:  https://lovingitvegan.com/tofu-burger/
# # 4 -url:  https://lovingitvegan.com/vegan-teriyaki-sauce/
# # 7 -url:  https://lovingitvegan.com/spicy-thai-carrot-sweet-potato-soup/
# # 5 -url:  https://lovingitvegan.com/vegan-french-onion-dip/
# # 6 -url:  https://lovingitvegan.com/vegan-bbq-sauce/
# # 9 -url:  https://lovingitvegan.com/vegan-sour-cream/
# # 13 -url:  https://lovingitvegan.com/vegan-sloppy-joes/
# # 8 -url:  https://lovingitvegan.com/vegan-worcestershire-sauce/
# # 7 -url:  https://lovingitvegan.com/hummus-pasta/
# # 5 -url:  https://lovingitvegan.com/vegan-bread-pudding/
# # 3 -url:  https://lovingitvegan.com/vegan-buffalo-sauce/
# # 14 -url:  https://lovingitvegan.com/vegan-bolognese/
# # 12 -url:  https://lovingitvegan.com/vegan-cauliflower-cheese/
# # 6 -url:  https://lovingitvegan.com/green-juice/
# # 7 -url:  https://lovingitvegan.com/vegan-ham/
# # 7 -url:  https://lovingitvegan.com/vegan-spinach-dip/
# # 11 -url:  https://lovingitvegan.com/cherry-smoothie/
# # 11 -url:  https://lovingitvegan.com/gluten-free-vegan-vanilla-cupcakes/
# # 6 -url:  https://lovingitvegan.com/vegan-vanilla-pudding/
# # 10 -url:  https://lovingitvegan.com/vegan-katsu-curry/
# # 16 -url:  https://lovingitvegan.com/vegan-biscuits/
# # 4 -url:  https://lovingitvegan.com/vegan-cannelloni/
# # 7 -url:  https://lovingitvegan.com/tofu-ricotta/
# # 11 -url:  https://lovingitvegan.com/vegan-anzac-biscuits/
# # 5 -url:  https://lovingitvegan.com/vegan-mince/
# # 12 -url:  https://lovingitvegan.com/vegan-zucchini-bread/
# # 8 -url:  https://lovingitvegan.com/green-tea-cupcakes/
# # 4 -url:  https://lovingitvegan.com/vegan-mushroom-pate/
# # 7 -url:  https://lovingitvegan.com/roasted-butternut-green-curry-soup-with-garlic-bread/
# # 13 -url:  https://lovingitvegan.com/vegan-red-velvet-cupcakes/
# # 4 -url:  https://lovingitvegan.com/vegan-cream-of-mushroom-soup/
# # 5 -url:  https://lovingitvegan.com/vegan-soda-bread/
# # 16 -url:  https://lovingitvegan.com/vegan-funfetti-cupcakes/
# # 2 -url:  https://lovingitvegan.com/vegan-chow-mein/
# # 4 -url:  https://lovingitvegan.com/vegan-gluten-free-banana-bread/
# # 12 -url:  https://lovingitvegan.com/vegan-carrot-cake-cupcakes/
# # 8 -url:  https://lovingitvegan.com/vegan-coleslaw/
# # 2 -url:  https://lovingitvegan.com/vegan-camembert/
# # 4 -url:  https://lovingitvegan.com/vegan-salami/
# # 8 -url:  https://lovingitvegan.com/vegan-custard/
# # 7 -url:  https://lovingitvegan.com/vegan-strawberry-cupcakes/
# # 6 -url:  https://lovingitvegan.com/tofu-steak/
# # 7 -url:  https://lovingitvegan.com/vegan-peppercorn-sauce/
# # 6 -url:  https://lovingitvegan.com/vegan-chocolate-cake-recipe/
# # 5 -url:  https://lovingitvegan.com/banana-bread-muffins/
# # 5 -url:  https://lovingitvegan.com/portobello-steaks/
# # 6 -url:  https://lovingitvegan.com/vegan-lo-mein/
# # 5 -url:  https://lovingitvegan.com/vegan-vodka-sauce/
# # 6 -url:  https://lovingitvegan.com/vegan-sausages/
# # 16 -url:  https://lovingitvegan.com/vegan-coffee-cake-with-kahlua-frosting/
# # 3 -url:  https://lovingitvegan.com/portobello-burgers/
# # 16 -url:  https://lovingitvegan.com/vegan-strawberry-cake/
# # 2 -url:  https://lovingitvegan.com/vegan-pate/
# # 10 -url:  https://lovingitvegan.com/vegan-stuffed-shells/
# # 4 -url:  https://lovingitvegan.com/vegan-sticky-toffee-pudding/
# # 9 -url:  https://lovingitvegan.com/vegan-cabbage-soup/
# # 15 -url:  https://lovingitvegan.com/chickpea-meatballs/
# # 4 -url:  https://lovingitvegan.com/vegan-victoria-sponge/
# # 4 -url:  https://lovingitvegan.com/vegan-spring-rolls/
# # 8 -url:  https://lovingitvegan.com/vegan-fried-rice/
# # 8 -url:  https://lovingitvegan.com/make-roasted-garlic/
# # 16 -url:  https://lovingitvegan.com/vegan-brownies/
# # 11 -url:  https://lovingitvegan.com/vegan-pancakes/
# # 5 -url:  https://lovingitvegan.com/vegan-broccoli-soup/
# # 15 -url:  https://lovingitvegan.com/vegan-spinach-artichoke-dip-the-best/
# # 10 -url:  https://lovingitvegan.com/vegan-chocolate-cake/
# # 12 -url:  https://lovingitvegan.com/vegan-tikka-masala/
# # 9 -url:  https://lovingitvegan.com/peaches-and-cream-chia-pudding/
# # 5 -url:  https://lovingitvegan.com/vegan-peach-cobbler/
# # 15 -url:  https://lovingitvegan.com/vegan-banana-bread/
# # 11 -url:  https://lovingitvegan.com/vegan-black-bean-soup/
# # 11 -url:  https://lovingitvegan.com/gluten-free-chocolate-cake-with-chocolate-ganache-frosting/
# # 10 -url:  https://lovingitvegan.com/vegan-ricotta/
# # 13 -url:  https://lovingitvegan.com/vegan-wellington/
# # 9 -url:  https://lovingitvegan.com/vegan-carrot-cake-balls/
# # 4 -url:  https://lovingitvegan.com/vegan-pot-pie/
# # 10 -url:  https://lovingitvegan.com/vegan-gingersnap-cookies/
# # 6 -url:  https://lovingitvegan.com/vegan-fruit-nut-chocolate-bark/
# # 13 -url:  https://lovingitvegan.com/vegan-chocolate-peanut-butter-cookies/
# # 7 -url:  https://lovingitvegan.com/vegan-pecan-pie/
# # 8 -url:  https://lovingitvegan.com/vegan-molasses-cookies/
# # 7 -url:  https://lovingitvegan.com/gingerbread-cake-with-orange-frosting/
# # 7 -url:  https://lovingitvegan.com/vegan-cheese-ball/
# # 13 -url:  https://lovingitvegan.com/vegan-white-cake/
# # 15 -url:  https://lovingitvegan.com/vegan-mac-and-cheese/
# # 16 -url:  https://lovingitvegan.com/vegan-meatloaf/
# # 9 -url:  https://lovingitvegan.com/vegan-green-bean-casserole/
# # 14 -url:  https://lovingitvegan.com/vegan-gluten-free-chocolate-cake/
# # 12 -url:  https://lovingitvegan.com/roasted-garlic-vegan-mashed-potatoes/
# # 12 -url:  https://lovingitvegan.com/2-ingredient-vegan-chocolate-crunch-bars/
# # 13 -url:  https://lovingitvegan.com/vegan-chocolate-ganache/
# # 16 -url:  https://lovingitvegan.com/vegan-butter-chicken/
# # 3 -url:  https://lovingitvegan.com/chocolate-peanut-butter-balls/
# # 3 -url:  https://lovingitvegan.com/pumpkin-pie-smoothie/
# # 3 -url:  https://lovingitvegan.com/vegan-mashed-sweet-potatoes/
# # 15 -url:  https://lovingitvegan.com/soft-chewy-vegan-chocolate-chip-cookies/
# # 4 -url:  https://lovingitvegan.com/grilled-tofu/
# # 4 -url:  https://lovingitvegan.com/vegan-blondies/
# # 7 -url:  https://lovingitvegan.com/vegan-pumpkin-fudge/
# # 6 -url:  https://lovingitvegan.com/vegan-mushroom-stroganoff/
# # 14 -url:  https://lovingitvegan.com/vegan-pumpkin-pie/
# # 14 -url:  https://lovingitvegan.com/crunchy-vegan-peanut-butter-cookies/
# # 7 -url:  https://lovingitvegan.com/vegan-falafel-recipe/
# # 10 -url:  https://lovingitvegan.com/vegan-peanut-butter-cups/
# # 9 -url:  https://lovingitvegan.com/chocolate-dessert-hummus/
# # 8 -url:  https://lovingitvegan.com/roasted-butternut-squash-salad/
# # 5 -url:  https://lovingitvegan.com/vegan-granola-bars/
# # 11 -url:  https://lovingitvegan.com/vegan-cheesecake/
# # 15 -url:  https://lovingitvegan.com/roasted-butternut-squash-soup/
# # 16 -url:  https://lovingitvegan.com/vegan-pumpkin-bread/
# # 5 -url:  https://lovingitvegan.com/vegan-jalapeno-poppers/
# # 11 -url:  https://lovingitvegan.com/linguine-with-garlic-chili-peanut-sauce/
# # 5 -url:  https://lovingitvegan.com/pumpkin-hummus/
# # 9 -url:  https://lovingitvegan.com/ratatouille/
# # 6 -url:  https://lovingitvegan.com/creamy-vegan-mushroom-risotto/
# # 16 -url:  https://lovingitvegan.com/baked-tofu-and-vegetable-casserole-with-quinoa/
# # 7 -url:  https://lovingitvegan.com/vegan-corn-fritters/
# # 4 -url:  https://lovingitvegan.com/vegan-gravy/
# # 8 -url:  https://lovingitvegan.com/roasted-garlic-hummus/
# # 13 -url:  https://lovingitvegan.com/vegan-enchiladas/
# # 15 -url:  https://lovingitvegan.com/vegan-apple-pie/
# # 6 -url:  https://lovingitvegan.com/how-to-make-cashew-butter/
# # 7 -url:  https://lovingitvegan.com/vegan-tiramisu/
# # 12 -url:  https://lovingitvegan.com/vegan-blueberry-pancakes/
# # 10 -url:  https://lovingitvegan.com/creamy-avocado-hummus/
# # 6 -url:  https://lovingitvegan.com/vegan-buddha-bowl/
# # 13 -url:  https://lovingitvegan.com/teriyaki-tofu/
# # 9 -url:  https://lovingitvegan.com/eggplant-dip/
# # 15 -url:  https://lovingitvegan.com/vegan-zucchini-brownies/
# # 2 -url:  https://lovingitvegan.com/vegan-gyros/
# # 14 -url:  https://lovingitvegan.com/vegan-mozzarella/
# # 6 -url:  https://lovingitvegan.com/roasted-butternut-squash-hummus/
# # 13 -url:  https://lovingitvegan.com/vegan-black-bean-burgers/
# # 14 -url:  https://lovingitvegan.com/sticky-vegan-malva-pudding/
# # 12 -url:  https://lovingitvegan.com/vegan-chocolate-muffins/
# # 10 -url:  https://lovingitvegan.com/lentil-dal/
# # 6 -url:  https://lovingitvegan.com/vegan-black-bean-brownies/
# # 10 -url:  https://lovingitvegan.com/baked-tofu/
# # 10 -url:  https://lovingitvegan.com/kale-smoothie/
# # 9 -url:  https://lovingitvegan.com/vegan-caramel-cream-pie/
# # 16 -url:  https://lovingitvegan.com/almond-butter-overnight-oats/
# # 11 -url:  https://lovingitvegan.com/homemade-peanut-butter/
# # 4 -url:  https://lovingitvegan.com/vegetable-and-pinto-bean-soup/
# # 11 -url:  https://lovingitvegan.com/chocolate-chip-peanut-butter-pancakes/
# # 5 -url:  https://lovingitvegan.com/how-to-make-almond-butter/
# # 13 -url:  https://lovingitvegan.com/white-bread/
# # 12 -url:  https://lovingitvegan.com/oreo-cupcakes/
# # 4 -url:  https://lovingitvegan.com/vegan-taco-meat/
# # 2 -url:  https://lovingitvegan.com/spicy-hummus/
# # 10 -url:  https://lovingitvegan.com/vegan-banana-muffins/
# # 6 -url:  https://lovingitvegan.com/vegan-lentil-soup/
# # 12 -url:  https://lovingitvegan.com/fried-tofu/
# # 9 -url:  https://lovingitvegan.com/vegan-coconut-pancakes/
# # 3 -url:  https://lovingitvegan.com/vegan-potato-salad/
# # 16 -url:  https://lovingitvegan.com/vegan-macaroons/
# # 8 -url:  https://lovingitvegan.com/vegan-pasta-salad/
# # 14 -url:  https://lovingitvegan.com/marinated-tofu/
# # 5 -url:  https://lovingitvegan.com/vegan-mushroom-gravy/
# # 11 -url:  https://lovingitvegan.com/vegan-scalloped-potatoes/
# # 8 -url:  https://lovingitvegan.com/vegan-lasagna/
# # 7 -url:  https://lovingitvegan.com/vegan-snickers-bars-gluten-free/
# # 3 -url:  https://lovingitvegan.com/vegan-ramen/
# # 15 -url:  https://lovingitvegan.com/cheesy-garlic-vegan-alfredo-30-minutes/
# # 15 -url:  https://lovingitvegan.com/vegan-parmesan-cheese/
# # 4 -url:  https://lovingitvegan.com/vegan-tartar-sauce/
# # 16 -url:  https://lovingitvegan.com/oatmeal-crunchies/
# # 12 -url:  https://lovingitvegan.com/vegan-chocolate-coconut-bars/
# # 6 -url:  https://lovingitvegan.com/vegan-frittata/
# # 16 -url:  https://lovingitvegan.com/vegan-peppermint-chocolate-mousse/
# # 11 -url:  https://lovingitvegan.com/vegan-peppermint-patties/
# # 2 -url:  https://lovingitvegan.com/vegan-curry/
# # 16 -url:  https://lovingitvegan.com/vegan-cornbread/
# # 6 -url:  https://lovingitvegan.com/vegan-chocolate-mousse/
# # 5 -url:  https://lovingitvegan.com/vegan-peppermint-milkshakes/
# # 7 -url:  https://lovingitvegan.com/3-ingredient-vegan-crepes/
# # 13 -url:  https://lovingitvegan.com/vegan-french-toast/
# # 4 -url:  https://lovingitvegan.com/vegan-paella/
# # 7 -url:  https://lovingitvegan.com/roasted-red-pepper-hummus/
# # 7 -url:  https://lovingitvegan.com/vegan-blackberry-muffins/
# # 8 -url:  https://lovingitvegan.com/caramel-fudge-vegan-chocolates/
# # 6 -url:  https://lovingitvegan.com/vegan-chocolate-covered-strawberries/
# # 7 -url:  https://lovingitvegan.com/sun-dried-tomato-pesto/
# # 13 -url:  https://lovingitvegan.com/vegan-queso/
# # 5 -url:  https://lovingitvegan.com/vegan-quiche/
# # 6 -url:  https://lovingitvegan.com/vegan-chocolate-pie/
# # 3 -url:  https://lovingitvegan.com/vegan-pho/
# # 11 -url:  https://lovingitvegan.com/vegan-asparagus-soup/
# # 3 -url:  https://lovingitvegan.com/vegan-tuna/
# # 6 -url:  https://lovingitvegan.com/vegan-ranch-dressing/
# # 7 -url:  https://lovingitvegan.com/vegan-baileys/
# # 6 -url:  https://lovingitvegan.com/vegan-hot-chocolate/
# # 3 -url:  https://lovingitvegan.com/vegan-chocolate-peppermint-fudge/
# # 4 -url:  https://lovingitvegan.com/microwave-peanut-butter-fudge-vegan-and-gluten-free/
# # 9 -url:  https://lovingitvegan.com/vegan-peppermint-ice-cream/
# # 11 -url:  https://lovingitvegan.com/chocolate-peanut-butter-fudge/
# # 11 -url:  https://lovingitvegan.com/vegan-nut-roast/
# # 8 -url:  https://lovingitvegan.com/microwave-chocolate-fudge/
# # 3 -url:  https://lovingitvegan.com/vegan-broccoli-cheese-soup/
# # 10 -url:  https://lovingitvegan.com/top-deck-no-bake-brownies/
# # 9 -url:  https://lovingitvegan.com/vegan-eggnog/
# # 8 -url:  https://lovingitvegan.com/sweet-basil-and-chive-cashew-cream/
# # 7 -url:  https://lovingitvegan.com/portobello-mushrooms-with-garlic-and-avocado/
# # 7 -url:  https://lovingitvegan.com/tofu-salad/
# # 14 -url:  https://lovingitvegan.com/vegan-hollandaise-sauce/
# # 13 -url:  https://lovingitvegan.com/vegan-caramel-sauce/
# # 3 -url:  https://lovingitvegan.com/vegan-pumpkin-spice-latte/
# # 3 -url:  https://lovingitvegan.com/vegan-sweet-potato-casserole/
# # 11 -url:  https://lovingitvegan.com/gluten-free-vanilla-protein-pancakes/
# # 10 -url:  https://lovingitvegan.com/quinoa-salad/
# # 8 -url:  https://lovingitvegan.com/tahini-mushroom-sauce-over-penne/
# # 16 -url:  https://lovingitvegan.com/vegan-lemon-curd/
# # 11 -url:  https://lovingitvegan.com/vegan-sweet-potato-pie/
# # 16 -url:  https://lovingitvegan.com/how-to-make-almond-milk/
# # 15 -url:  https://lovingitvegan.com/vegan-chocolate-donuts/
# # 6 -url:  https://lovingitvegan.com/vegan-pumpkin-pancakes/
# # 12 -url:  https://lovingitvegan.com/vegan-pumpkin-muffins/
# # 9 -url:  https://lovingitvegan.com/vegan-pepperoni/
# # 4 -url:  https://lovingitvegan.com/vegan-split-pea-soup/
# # 14 -url:  https://lovingitvegan.com/vegan-gluten-free-pancakes/
# # 6 -url:  https://lovingitvegan.com/vegan-tofu-stir-fry/
# # 11 -url:  https://lovingitvegan.com/vegan-peanut-butter-squares/
# # 12 -url:  https://lovingitvegan.com/vegan-protein-shake/
# # 11 -url:  https://lovingitvegan.com/baked-vegan-donuts/
# # 15 -url:  https://lovingitvegan.com/vegan-bacon/
# # 3 -url:  https://lovingitvegan.com/vegan-ice-cream/
# # 11 -url:  https://lovingitvegan.com/homemade-twix-bars/
# # 9 -url:  https://lovingitvegan.com/vegan-burrito-bowls/
# # 8 -url:  https://lovingitvegan.com/dairy-free-cheesecake/
# # 3 -url:  https://lovingitvegan.com/vegan-chickpea-salad/
# # 11 -url:  https://lovingitvegan.com/vegan-carrot-ginger-soup/
# # 3 -url:  https://lovingitvegan.com/vegan-greek-salad/
# # 3 -url:  https://lovingitvegan.com/vinaigrette/
# # 14 -url:  https://lovingitvegan.com/vegan-gumbo/
# # 13 -url:  https://lovingitvegan.com/dairy-free-chocolate-cake/
# # 16 -url:  https://lovingitvegan.com/vegan-lemon-bars/
# # 7 -url:  https://lovingitvegan.com/vegan-stew/
# # 11 -url:  https://lovingitvegan.com/vegan-chocolate-tart/
# # 11 -url:  https://lovingitvegan.com/olive-tapenade/
# # 16 -url:  https://lovingitvegan.com/vegan-chocolate-buttercream-frosting/
# # 6 -url:  https://lovingitvegan.com/vegan-corn-chowder/
# # 3 -url:  https://lovingitvegan.com/vegan-mushroom-sauce/
# # 7 -url:  https://lovingitvegan.com/vegan-mug-cake/
# # 6 -url:  https://lovingitvegan.com/vegan-miso-soup/
# # 11 -url:  https://lovingitvegan.com/simple-guacamole-recipe/
# # 10 -url:  https://lovingitvegan.com/vegan-orange-cake/
# # 12 -url:  https://lovingitvegan.com/cashew-queso/
# # 7 -url:  https://lovingitvegan.com/vegan-strawberry-shortcake/
# # 2 -url:  https://lovingitvegan.com/vegan-carbonara/
# # 6 -url:  https://lovingitvegan.com/vegetable-skewers/
# # 16 -url:  https://lovingitvegan.com/vegan-banana-cookies/
# # 7 -url:  https://lovingitvegan.com/vegan-gluten-free-brownies/
# # 10 -url:  https://lovingitvegan.com/vegan-banana-ice-cream/
# # 2 -url:  https://lovingitvegan.com/vegan-mushroom-pasta/
# # 16 -url:  https://lovingitvegan.com/vegan-rice-pudding/
# # 8 -url:  https://lovingitvegan.com/vegan-chicken/
# # 8 -url:  https://lovingitvegan.com/easy-3-ingredient-vegan-nutella/
# # 7 -url:  https://lovingitvegan.com/how-to-make-cashew-nut-milk/
# # 15 -url:  https://lovingitvegan.com/vegan-tom-yum-soup/
# # 15 -url:  https://lovingitvegan.com/vegan-scrambled-eggs/
# # 14 -url:  https://lovingitvegan.com/vegan-moussaka/
# # 16 -url:  https://lovingitvegan.com/vegan-coffee-ice-cream/
# # 14 -url:  https://lovingitvegan.com/vegan-white-chocolate/
# # 11 -url:  https://lovingitvegan.com/general-tsos-tofu/
# # 8 -url:  https://lovingitvegan.com/vegan-gluten-free-carrot-cake/
# # 16 -url:  https://lovingitvegan.com/cashew-ice-cream/
# # 15 -url:  https://lovingitvegan.com/vegan-blue-cheese-dressing/
# # 16 -url:  https://lovingitvegan.com/vegan-cottage-cheese/
# # 14 -url:  https://lovingitvegan.com/vegan-pistachio-ice-cream/
# # 11 -url:  https://lovingitvegan.com/vegan-chocolate-sauce/
# # 15 -url:  https://lovingitvegan.com/vegan-gluten-free-chocolate-chip-cookies/
# # 14 -url:  https://lovingitvegan.com/vegan-chickpea-curry/
# # 3 -url:  https://lovingitvegan.com/vegan-buttercream-frosting/
# # 14 -url:  https://lovingitvegan.com/mango-chia-pudding/
# # 10 -url:  https://lovingitvegan.com/vegan-chocolate-avocado-mousse/
# # 15 -url:  https://lovingitvegan.com/vegan-peanut-sauce/
# # 12 -url:  https://lovingitvegan.com/vegan-hash-browns/
# # 3 -url:  https://lovingitvegan.com/vegan-green-goddess-dressing/
# # 6 -url:  https://lovingitvegan.com/vegan-strawberry-ice-cream/
# # 10 -url:  https://lovingitvegan.com/vegan-chocolate/
# # 13 -url:  https://lovingitvegan.com/vegan-tacos/
# # 7 -url:  https://lovingitvegan.com/tahini-sauce/
# # 3 -url:  https://lovingitvegan.com/vegan-cream-cheese-frosting/
# # 4 -url:  https://lovingitvegan.com/vegan-pizza/
# # 9 -url:  https://lovingitvegan.com/vegan-pea-soup/
# # 16 -url:  https://lovingitvegan.com/vegan-cinnamon-rolls/
# # 4 -url:  https://lovingitvegan.com/vegan-minestrone-soup/
# # 12 -url:  https://lovingitvegan.com/vegan-avocado-ice-cream/
# # 13 -url:  https://lovingitvegan.com/baked-vegan-mac-and-cheese/
# # 16 -url:  https://lovingitvegan.com/vegan-cream-cheese/
# # 3 -url:  https://lovingitvegan.com/vegan-lentil-curry/
# # 3 -url:  https://lovingitvegan.com/vegan-chocolate-brownies/
# # 14 -url:  https://lovingitvegan.com/vegan-pesto-pasta-pan-roasted-cherry-tomatoes/
# # 16 -url:  https://lovingitvegan.com/vegan-banana-oatmeal-cookies/
# # 4 -url:  https://lovingitvegan.com/vegan-bruschetta/
# # 4 -url:  https://lovingitvegan.com/vegan-zucchini-soup/
# # 2 -url:  https://lovingitvegan.com/vegan-oreo-cake/
# # 16 -url:  https://lovingitvegan.com/vegan-zucchini-fritters/
# # 11 -url:  https://lovingitvegan.com/vegan-chocolate-cupcakes/
# # 9 -url:  https://lovingitvegan.com/vegan-coconut-curry/
# # 11 -url:  https://lovingitvegan.com/vegan-cauliflower-soup/
# # 16 -url:  https://lovingitvegan.com/best-vegan-chocolate-cake/
# # 2 -url:  https://lovingitvegan.com/vegan-korma/
# # 9 -url:  https://lovingitvegan.com/vegan-pina-colada/
# # 14 -url:  https://lovingitvegan.com/vegan-toffee/
# # 6 -url:  https://lovingitvegan.com/vegan-nachos/
# # 8 -url:  https://lovingitvegan.com/vegan-peppermint-bark/
# # 14 -url:  https://lovingitvegan.com/vegan-tomato-basil-soup/
# # 10 -url:  https://lovingitvegan.com/vegan-burrito/
# # 8 -url:  https://lovingitvegan.com/pico-de-gallo/
# # 13 -url:  https://lovingitvegan.com/vegan-chocolate-banana-bread/
# # 9 -url:  https://lovingitvegan.com/vegan-cauliflower-mashed-potatoes/
# # 14 -url:  https://lovingitvegan.com/vegan-cheddar-cheese/
# # 3 -url:  https://lovingitvegan.com/vegan-apple-crisp/
# # 4 -url:  https://lovingitvegan.com/vegan-apple-cake/
# # 9 -url:  https://lovingitvegan.com/vegan-garlic-bread/
# # 9 -url:  https://lovingitvegan.com/vegan-pineapple-upside-down-cake/
# # 13 -url:  https://lovingitvegan.com/vegan-funfetti-cake/
# # 7 -url:  https://lovingitvegan.com/vegan-key-lime-pie/
# # 7 -url:  https://lovingitvegan.com/homemade-salsa/
# # 4 -url:  https://lovingitvegan.com/vegan-almond-butter-cookies/
# # 3 -url:  https://lovingitvegan.com/vegan-pesto/
# # 6 -url:  https://lovingitvegan.com/vegan-coconut-cookies/
# # 12 -url:  https://lovingitvegan.com/vegan-pumpkin-cheesecake/
# # 3 -url:  https://lovingitvegan.com/vegan-pumpkin-cookies/
# # 15 -url:  https://lovingitvegan.com/vegan-nacho-cheese/
# # 6 -url:  https://lovingitvegan.com/vegan-sweet-potato-soup/
# # 7 -url:  https://lovingitvegan.com/vegan-thousand-island/
# # 7 -url:  https://lovingitvegan.com/vegan-almond-butter-fudge/
# # 7 -url:  https://lovingitvegan.com/vegan-caesar-salad/
# # 13 -url:  https://lovingitvegan.com/vegan-aioli/
# # 6 -url:  https://lovingitvegan.com/vegan-kale-salad/
# # 15 -url:  https://lovingitvegan.com/vegan-caesar-dressing/
# # 4 -url:  https://lovingitvegan.com/vegan-lemon-cookies/
# # 9 -url:  https://lovingitvegan.com/peanut-butter-banana-ice-cream/
# # 3 -url:  https://lovingitvegan.com/vegan-couscous-salad/
# # 5 -url:  https://lovingitvegan.com/vegan-oatmeal-raisin-cookies/
# # 1 -url:  https://lovingitvegan.com/vegan-german-chocolate-cake/
# # 5 -url:  https://lovingitvegan.com/vegan-sweet-potato-salad/
# # 14 -url:  https://lovingitvegan.com/vegan-energy-balls/
# # 4 -url:  https://lovingitvegan.com/kung-pao-tofu/
# # 6 -url:  https://lovingitvegan.com/tahini-salad-dressing/
# # 5 -url:  https://lovingitvegan.com/vegan-zucchini-muffins/
# # 9 -url:  https://lovingitvegan.com/vegan-sweet-potato-curry/
# # 2 -url:  https://lovingitvegan.com/vegan-banana-pancakes/
# # 9 -url:  https://lovingitvegan.com/vegan-coffee-smoothie/
# # 8 -url:  https://lovingitvegan.com/vegan-shepherds-pie/
# # 2 -url:  https://lovingitvegan.com/vegan-lemon-pound-cake/
# # 12 -url:  https://lovingitvegan.com/vegan-potato-curry/
# # 9 -url:  https://lovingitvegan.com/chocolate-peanut-butter-smoothie/
# # 3 -url:  https://lovingitvegan.com/vegan-peanut-butter-oatmeal-cookies/
